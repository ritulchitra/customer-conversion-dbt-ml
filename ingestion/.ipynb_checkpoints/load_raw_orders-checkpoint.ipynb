# %%
import os
import pandas as pd

print("Current working directory:")
print(os.getcwd())
# Out:
# Current working directory:
# C:\Users\ritul\OneDrive\Desktop\Projects\customer-conversion-dbt-ml\ingestion

# %%
from dotenv import load_dotenv

load_dotenv()

print("DB_HOST:", os.getenv("DB_HOST"))
print("DB_NAME:", os.getenv("DB_NAME"))
print("DB_USER:", os.getenv("DB_USER"))
print("DB_PORT:", os.getenv("DB_PORT"))
# Out:
# DB_HOST: db.wovoiyojphtakfevbdcj.supabase.co
# DB_NAME: postgres
# DB_USER: postgres
# DB_PORT: 5432

# %%
csv_path = r"C:\Users\ritul\OneDrive\Desktop\Projects\customer-conversion-dbt-ml\data\Online_Retail.csv"

df = pd.read_csv(
    csv_path,
    encoding="ISO-8859-1"
)

df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df = df[
    [
        "InvoiceNo",
        "StockCode",
        "Description",
        "Quantity",
        "InvoiceDate",
        "UnitPrice",
        "CustomerID",
        "Country",
    ]
]

df.shape, df.columns
# Out:
# ((541909, 8),
#  Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#         'UnitPrice', 'CustomerID', 'Country'],
#        dtype='object'))

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Prepairing Data Base Connection

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

password = quote_plus(os.getenv("DB_PASSWORD"))

engine = create_engine(
    f"postgresql+psycopg2://{os.getenv('DB_USER')}:{password}"
    f"@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}",
    connect_args={"sslmode": "require"},
)
print('Success')
# Out:
# Success

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("select 1"))
    print("DB connection successful:", result.scalar())
# Out:
# DB connection successful: 1

# %%
# Align DataFrame columns to database (lowercase)
df.columns = [c.lower() for c in df.columns]

df.columns
# Out:
# Index(['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'unitprice', 'customerid', 'country'],
#       dtype='object')

# %%
df.head(10).to_sql(
    "raw_orders",
    engine,
    if_exists="append",
    index=False
)

print("Inserted 10 rows successfully")
# Out:
# Inserted 10 rows successfully

# %%
from sqlalchemy import text

with engine.connect() as conn:
    count = conn.execute(text("select count(*) from raw_orders")).scalar()
    print("Rows in raw_orders:", count)
# Out:
# Rows in raw_orders: 10

# %%
df.to_sql(
    "raw_orders",
    engine,
    if_exists="append",
    index=False,
    chunksize=5000
)

print("FULL raw_orders load completed")

# %%
with engine.connect() as conn:
    count = conn.execute("select count(*) from raw_orders").scalar()
    print("FINAL row count:", count)
